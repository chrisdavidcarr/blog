# %% [raw]
# ---
# title: "Introducing Opinni"
# author: "Chris Carr"
# date: "2025-04-18"
# categories: [news, startups]
# image: "image.jpg"
# draft: true
# ---

# %% [markdown]
# This is a test blog post!
